# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('./exports/diabetes_binary_5050split_BRFSS2019.csv')
df2 = pd.read_csv('./exports/diabetes_binary_5050split_BRFSS2017.csv')

combine = [df1, df2]
  
result = pd.concat(combine)

# %%
result.count()
# Out:
# Diabetes_binary         148383
# HighBP                  148383
# BMI                     148383
# Smoker                  148383
# Stroke                  148383
# HeartDiseaseorAttack    148383
# PhysActivity            148383
# Fruits                  148383
# Veggies                 148383
# HvyAlcoholConsump       148383
# HighChol                148383
# AnyHealthcare           148383
# NoDocbcCost             148383
# GenHlth                 148383
# MentHlth                148383
# PhysHlth                148383
# DiffWalk                148383
# Sex                     148383
# Age                     148383
# Education               148383
# Income                  148383
# dtype: int64

# %%
result.tail()
# Out:
#        Diabetes_binary  HighBP   BMI  Smoker  Stroke  HeartDiseaseorAttack  \
# 77737              1.0       0  28.0     0.0     0.0                   0.0
# 77738              1.0       1  40.0     0.0     0.0                   0.0
# 77739              1.0       0  32.0     1.0     0.0                   0.0
# 77740              1.0       1  25.0     1.0     0.0                   0.0
# 77741              1.0       0  34.0     0.0     0.0                   0.0
#
#        PhysActivity  Fruits  Veggies  HvyAlcoholConsump  ...  AnyHealthcare  \
# 77737             0       0        0                  0  ...            1.0
# 77738             1       0        0                  0  ...            1.0
# 77739             1       0        1                  0  ...            1.0
# 77740             0       0        0                  0  ...            1.0
# 77741             0       0        0                  0  ...            1.0
#
# ...

# %%
# need to reset index as it doesn't tally
result = result.reset_index(drop=True)
result.tail()
# Out:
#         Diabetes_binary  HighBP   BMI  Smoker  Stroke  HeartDiseaseorAttack  \
# 148378              1.0       0  28.0     0.0     0.0                   0.0
# 148379              1.0       1  40.0     0.0     0.0                   0.0
# 148380              1.0       0  32.0     1.0     0.0                   0.0
# 148381              1.0       1  25.0     1.0     0.0                   0.0
# 148382              1.0       0  34.0     0.0     0.0                   0.0
#
#         PhysActivity  Fruits  Veggies  HvyAlcoholConsump  ...  AnyHealthcare  \
# 148378             0       0        0                  0  ...            1.0
# 148379             1       0        0                  0  ...            1.0
# 148380             1       0        1                  0  ...            1.0
# 148381             0       0        0                  0  ...            1.0
# 148382             0       0        0                  0  ...            1.0
#
# ...

# %%
result.to_csv('./exports/diabetes_binary_5050split_BRFSS2017and2019.csv', sep=',', index=0)
